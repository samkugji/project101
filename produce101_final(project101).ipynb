# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
#!/usr/bin/env/ python3
#-*- coding: utf-8 -*-

# %%
from __future__ import division
from __future__ import print_function
from sklearn import svm
from pip.req.req_file import preprocess
from mistune import preprocessing
from numpy import newaxis
from sklearn.linear_model.base import LinearRegression
from sklearn.preprocessing import scale
import statsmodels.regression
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import matplotlib as mpl
import matplotlib.pylab as plt
import seaborn as sns
import sklearn as sk
import pickle

sns.set()

plt.rc('font',family='AppleGothic')

import sys
print(sys.stdin.encoding, sys.stdout.encoding)
# Out:
# UTF-8 UTF-8

# %%
# OLS 그려주는 함수 만들기

def OLS_result(y, x) : 
    model_OLS = sm.OLS(y, x) 
    result_OLS = model_OLS.fit()
#     print(result_OLS.summary())
    
    return result_OLS

# %%
# OLS fit_regularized 그려주는 함수 만들기
def OLS_regularized(y, x, alpha) : 
    model_OLS = sm.OLS(y, x) 
    result_OLS = model_OLS.fit_regularized(alpha=alpha)
    
    return result_OLS

# %%
# Dataframe 전체 출력 함수

def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %% [markdown]
# # What is Project 101?
#
# - 서바이벌 방송 프로그램 프로듀스101(m-net)의 데이터 분석 및 결과 추정
# - Analyze TV show named Produce101 (Estimate your girls)
#
#
# ![What is Produce 101](Images/whatisproduce101.jpg)

# %% [markdown]
# # What is Project 101?
#
# - 서바이벌 방송 프로그램 프로듀스101(m-net)의 데이터 분석 및 결과 추정
# - Analyze TV show named Produce101 (Estimate your girls)
#
# ![What is Produce 101_3](Images/votepage.png)

# %% [markdown]
# # Data
# - [crawling from m-net webpage](http://mnettv.interest.me/produce101/page/p101.page.profile.dbp?id=88)
# - put into dataframe with the Python

# %% [markdown]
# # Data
#
# ### 1. SAMPLE : 97 people (retire 4 people)
#
# ### 2. TAGET (Y)
# - votes : 엠넷 홈페이지에서 1일 1명당 11표
# - votes : on m-net webpage with 1 person 11 votes in every day)
#
# ### 3. FEATURE (X1, X2, ..., X12)
# - expo_1 : 1차 방출평가 전에 Produce101 방송된 1회~4회까지 각 연습생의 방송 노출 시간
# - expo_2 : 2차 방출평가 전에 Produce101 방송된 5회~7회까지 각 연습생의 방송 노출 시간
#     - (출처 : [방송모니터위원회]Mnet 오디션 프로그램 <프로듀스 101> 모니터보고서(2016.3.25))
#
# - neg_1 : 1,2회 / 방송 후 부정적 여론 형성 (허찬미 : 인사 안함 논란, 1위자리 앉음 | 오서정 : 슈퍼스타K 안예슬 논란) [category]
# - order_name : 투표 홈페이지 이름 순으로 상위 11명 노출 여부 [category]
# - order_agency : 투표 홈페이지 소속사 순으로 상위 11명 노출 여부 [category]
# - level_1 : 1회, 2회 / 1차 레벨 평가 테스트 후 판정 (A:5 / B:4 / C:3 / D:2 / F:1) [category]
# - level_2 : 2회 / 2차 레벨 평가 테스트 후 판정 (A:5 / B:4 / C:3 / D:2 / F:1) [category]
# - age : 나이
# - height : 신장
# - visual : 연습생들이 직접 뽑은 비주얼 1~11위 [category]
# - agency_category : 소속 연예기획사 카테고리값 (대형:3 / 중소형:2 / 개인:1) [category]
#     - 연예 전문 웹진 분류 참고 : http://ize.co.kr/articleView.html?no=2016022121027299563
#
# - agency_member_count : 같은 소속사 연습생 수
# - is_ranker_same_agency_1 : 1차 방출평가 시 같은 소속사 연습생이 상위 11위에 포함되어 있는가? (Hard Carry) [category]
# - is_ranker_same_agency_2 : 2차 방출평가 시 같은 소속사 연습생이 상위 11위에 포함되어 있는가? (Hard Carry) [category]

# %% [markdown]
# # EDA(Exploratory data analysis)

# %%
produce101_df = pd.DataFrame.from_csv("produce101_raw.csv",
                                      index_col='name', encoding='utf-8')
produce101_df
# Out:
#                    agency  vote_1   vote_2  expo_1  expo_2  imp_1  imp_2  \
# name
# 김세정       Jellyfish(젤리피쉬)  559694  1473685     105     104     39      8
# 전소미                   JYP  528772  1201490     171      63     49     21
# 최유정                  판타지오  392773  1286447     134      71     10     50
# 주결경          PLEDIS(플레디스)  387537   885556       6      31     13      3
# 강미나       Jellyfish(젤리피쉬)  376977  1212720      34     100     33      8
# 기희현                   MBK  294540   481070      91      19     26      5
# 김다니                   MBK  273930   419427      52       9     28      1
# 정채연                   MBK  251469   696808      10      34     21      4
# 김나영       Jellyfish(젤리피쉬)  250552   931084      65      44     28      5
# 전소연                  CUBE  230395   372952      54      27     33      8
# 김소혜         REDLINE(레드라인)  227670   833101     163     128     40     15
# 유연정                  스타쉽   214691   684660      58      54      8      1
# 김도연                  판타지오  203007   841749      39       3     12     27
# 김청하                   M&H  193820   462668      69      15      5     54
# 허찬미                  더블킥   184926   249026     133      36     63     11
# 권은빈                  CUBE  179721   310972      43      32     29      4
# 응 씨 카이              초록뱀주나  176067   298495       4      52      3     87
# 정은우          PLEDIS(플레디스)  175904   438879       7      26      5      3
# 김주나              music K   161825   371978     202      62     40     23
# 박소연             LOEN (로엔)  156148   289217      32      35     14     85
# 윤채경                   DSP  149977   460700      43      66     23      6
# 한혜리     Star Empire(스타제국)  125095   450768      16      13      1     33
# 김소희                  뮤직웍스  109501   363818      16      13      9      2
# 임나영          PLEDIS(플레디스)  107785   665898      24      18      7      1
# 안예슬        MAJESTY(마제스티)   106322   301814      34      65      4     46
# 박시연          PLEDIS(플레디스)  105963   372295      16      61      7      0
# 조시윤                   DSP  102110   146681      25       7     22      9
# 강예빈          PLEDIS(플레디스)   88277   250556      62      19     14      3
# 윤서형        &August(&어거스트)   73558   187021     198       4     55      1
# 김서경                 개인연습생   72474   300125      42      18      0      8
# ...                   ...     ...      ...     ...     ...    ...    ...
# 김지성             Happyface   26566        0       0       0      1      0
# 김수현                   미스틱   26139        0      11       0      1      0
# 최은빈                   넥스타   25659        0      32       0      1      9
# 박민지             매직 프레쉬컴퍼니   24772        0      12       0      3      5
# 함예지                 스타플레닛   24485        0      14       0      8      6
# 김미소                   MJ    24114        0      38       0      0      1
# 김우정             Happyface   23795        0      51       0      1      0
# 허샘                    MJ    23722        0       8       0      1      2
# 한지연          MIDAS(마이다스)    23566        0       2       0      1      3
# 니와 시오리     MAJESTY(마제스티)    23045        0       0       0      2      8
# 편강윤            M2 project   21908        0       4       0      4      0
# 이수현             Happyface   21762        0      26       0      2      0
# 김홍은             Happyface   21598        0       1       0      0      0
# 김도희                 블레싱     21485        0       8       0      0      2
# 김설아               이큐브 미디어   21394        0       2       0      3      0
# 오한아름                블레싱     21245        0       9       0      0      2
# 김윤지     Star Empire(스타제국)   21206        0      43       0      0     23
# 이서정         LOUDers(라우더스)   21018        0       3       0      0      0
# 김자연             Happyface   20932        0      13       0      0      1
# 이채린          MIDAS(마이다스)    20868        0       1       0      0      3
# 최유빈          MIDAS(마이다스)    20829        0       8       0      1      3
# 캐서린 리        MIDAS(마이다스)    20807        0       2       0      1      3
# 신혜현          MIDAS(마이다스)    20752        0       7       0      0      1
# 남수진             매직 프레쉬컴퍼니   20189        0       0       0      0      6
# 김솔이                 블레싱     19899        0       6       0      0      0
# 이세흔      NEXTLEVEL(넥스트레벨)   18731        0      21       0      1      8
# 방준희                 블레싱     18579        0      10       0      0      0
# 윤유담                   FM    18206        0      23       0      0      9
# 김보선         LOUDers(라우더스)   18034        0      18       0      2      0
# 문현주                   넥스타   16736        0      13       0      0      0
#
#         neg_1  order_name  order_agency           ...             level_2  \
# name                                              ...
# 김세정         0           0             0           ...                   5
# 전소미         0           0             0           ...                   4
# 최유정         0           0             0           ...                   5
# 주결경         0           0             0           ...                   5
# 강미나         0           1             0           ...                   5
# 기희현         0           1             0           ...                   5
# 김다니         0           1             0           ...                   5
# 정채연         0           0             0           ...                   3
# 김나영         0           1             0           ...                   5
# 전소연         0           0             1           ...                   5
# 김소혜         0           0             0           ...                   1
# 유연정         0           0             0           ...                   5
# 김도연         0           0             0           ...                   5
# 김청하         0           0             0           ...                   5
# 허찬미         1           0             0           ...                   4
# 권은빈         0           1             1           ...                   2
# 응 씨 카이      0           0             0           ...                   4
# 정은우         0           0             0           ...                   4
# 김주나         0           0             0           ...                   1
# 박소연         0           0             0           ...                   5
# 윤채경         0           0             1           ...                   3
# 한혜리         0           0             0           ...                   2
# 김소희         0           0             0           ...                   3
# 임나영         0           0             0           ...                   5
# 안예슬         0           0             0           ...                   4
# 박시연         0           0             0           ...                   4
# 조시윤         0           0             1           ...                   2
# 강예빈         0           1             0           ...                   5
# 윤서형         0           0             1           ...                   2
# 김서경         0           0             0           ...                   5
# ...       ...         ...           ...           ...                 ...
# 김지성         0           0             0           ...                   4
# 김수현         0           0             0           ...                   2
# 최은빈         0           0             0           ...                   3
# 박민지         0           0             0           ...                   5
# 함예지         0           0             0           ...                   1
# 김미소         0           0             0           ...                   3
# 김우정         0           0             0           ...                   3
# 허샘          0           0             0           ...                   1
# 한지연         0           0             0           ...                   1
# 니와 시오리      0           0             0           ...                   4
# 편강윤         0           0             0           ...                   1
# 이수현         0           0             0           ...                   4
# 김홍은         0           0             0           ...                   1
# 김도희         0           0             0           ...                   1
# 김설아         0           0             0           ...                   1
# 오한아름        0           0             0           ...                   1
# 김윤지         0           0             0           ...                   4
# 이서정         0           0             0           ...                   2
# 김자연         0           0             0           ...                   2
# 이채린         0           0             0           ...                   2
# 최유빈         0           0             0           ...                   2
# 캐서린 리       0           0             0           ...                   1
# 신혜현         0           0             0           ...                   3
# 남수진         0           0             0           ...                   3
# 김솔이         0           0             0           ...                   1
# 이세흔         0           0             0           ...                   3
# 방준희         0           0             0           ...                   3
# 윤유담         0           0             1           ...                   2
# 김보선         0           0             0           ...                   2
# 문현주         0           0             0           ...                   1
#
#         age  height  visual  agency_category   id  \
# name
# 김세정      20   164.0       1                3   88
# 전소미      15   168.0       1                3   40
# 최유정      17   159.0       0                3   42
# 주결경      18   166.0       1                3  136
# 강미나      17   162.0       0                3   90
# 기희현      21   167.0       1                3  187
# 김다니      17   172.0       0                3  186
# 정채연      19   166.0       1                3  185
# 김나영      21   169.0       0                3   89
# 전소연      18   157.0       0                3  162
# 김소혜      17   163.0       0                2   72
# 유연정      17   167.0       0                3   63
# 김도연      17   170.0       1                3   45
# 김청하      20   161.0       0                2  103
# 허찬미      24   161.0       0                2  188
# 권은빈      16   167.0       1                3  164
# 응 씨 카이   22   165.0       0                2  202
# 정은우      18   167.0       0                3  137
# 김주나      22   168.0       0                2  218
# 박소연      17   168.0       0                3  165
# 윤채경      20   160.0       0                3   62
# 한혜리      19   159.0       0                3   91
# 김소희      21   162.0       0                2  197
# 임나영      21   171.0       0                3  138
# 안예슬      21   161.0       0                2  100
# 박시연      16   163.0       1                3  139
# 조시윤      20   160.0       0                3   61
# 강예빈      18   162.5       0                3  141
# 윤서형      21   163.0       0                2   74
# 김서경      17   155.0       0                1  169
# ...     ...     ...     ...              ...  ...
# 김지성      20   169.0       1                2  147
# 김수현      16   161.0       0                2  166
# 최은빈      23   163.0       0                2  198
# 박민지      17   164.0       0                2  174
# 함예지      22   167.3       0                2  222
# 김미소      16   165.0       0                2   55
# 김우정      24   162.0       0                2  149
# 허샘       23   166.0       0                2   53
# 한지연      21   167.0       0                2   94
# 니와 시오리   22   162.0       0                2  101
# 편강윤      24   167.8       0                2  223
# 이수현      20   161.0       1                2  145
# 김홍은      17   170.0       0                2  146
# 김도희      19   165.0       0                2  193
# 김설아      25   163.0       0                2  176
# 오한아름     18   162.0       0                2  189
# 김윤지      20   156.0       0                3   92
# 이서정      16   163.0       0                2  195
# 김자연      25   164.0       0                2  148
# 이채린      17   162.0       0                2   97
# 최유빈      17   161.0       0                2   96
# 캐서린 리    15   165.0       0                2   95
# 신혜현      17   162.0       0                2   98
# 남수진      21   168.0       0                2  175
# 김솔이      15   172.7       0                2  192
# 이세흔      17   159.0       0                2   73
# 방준희      18   164.0       0                2  191
# 윤유담      19   168.0       0                2  226
# 김보선      22   163.0       0                2  196
# 문현주      18   170.0       0                2  199
#
#                                             thumb_pic_url agency_member_count  \
# name
# 김세정     http://static.global.mnet.com/data/od/images/g...                   3
# 전소미     http://static.global.mnet.com/data/od/images/g...                   1
# 최유정     http://static.global.mnet.com/data/od/images/g...                   5
# 신혜현     http://static.global.mnet.com/data/od/images/g...                   6
# 남수진     http://static.global.mnet.com/data/od/images/g...                   2
# 김솔이     http://static.global.mnet.com/data/od/images/g...                   5
# 이세흔     http://static.global.mnet.com/data/od/images/g...                   1
# 방준희     http://static.global.mnet.com/data/od/images/g...                   5
# 윤유담     http://static.global.mnet.com/data/od/images/g...                   1
# 김보선     http://static.global.mnet.com/data/od/images/g...                   3
# 문현주     http://static.global.mnet.com/data/od/images/g...                   2
#
#         is_ranker_same_agency_1  is_ranker_same_agency_2
# name
# 김세정                           1                        1
# 전소미                           0                        0
# 최유정                           1                        1
# 주결경                           1                        1
# 강미나                           1                        1
# 기희현                           1                        1
# 김다니                           1                        1
# 정채연                           1                        1
# 김나영                           1                        1
# 전소연                           1                        0
# 김소혜                           0                        0
# 유연정                           0                        1
# 김도연                           1                        1
# 김청하                           0                        0
# 허찬미                           0                        0
# 권은빈                           1                        0
# 응 씨 카이                        0                        0
# 정은우                           1                        1
# 김주나                           0                        0
# 박소연                           0                        0
# 윤채경                           0                        0
# 한혜리                           0                        0
# 김소희                           0                        0
# 임나영                           1                        1
# 안예슬                           0                        0
# 박시연                           1                        1
# 조시윤                           0                        0
# 강예빈                           1                        1
# 윤서형                           0                        0
# 김서경                           0                        0
# ...                         ...                      ...
# 김지성                           0                        0
# 김수현                           0                        0
# 최은빈                           0                        0
# 박민지                           0                        0
# 함예지                           0                        0
# 김미소                           0                        0
# 김우정                           0                        0
# 허샘                            0                        0
# 한지연                           0                        0
# 니와 시오리                        0                        0
# 편강윤                           0                        0
# 이수현                           0                        0
# 김홍은                           0                        0
# 김도희                           0                        0
# 김설아                           0                        0
# 오한아름                          0                        0
# 김윤지                           0                        0
# 이서정                           0                        0
# 김자연                           0                        0
# 이채린                           0                        0
# 최유빈                           0                        0
# 캐서린 리                         0                        0
# 신혜현                           0                        0
# 남수진                           0                        0
# 김솔이                           0                        0
# 이세흔                           0                        0
# 방준희                           0                        0
# 윤유담                           0                        0
# 김보선                           0                        0
# 문현주                           0                        0
#
# [97 rows x 21 columns]

# %%
# First EDA(Exploratory data analysis) with vote_1(target)

# sns.pairplot(produce101_df, diag_kind="kde", kind="reg"
#              ,vars = ['expo_1', 'neg_1', 'order_name', 'order_agency',
#                       'level_2', 'agency_category', 'age', 'height', 'visual', 'agency_member_count'
#                       ,'is_ranker_same_agency_1','is_ranker_same_agency_2', 'vote_1'], size=5)
# plt.show()

# %% [markdown]
# # What can I do?
#
# - OLS Regression
#     - In statistics, ordinary least squares (OLS) or linear least squares is a method for estimating the unknown parameters in a linear regression model, with the goal of minimizing the differences between the observed responses in some arbitrary dataset and the responses predicted by the linear approximation of the data (visually this is seen as the sum of the vertical distances between each data point in the set and the corresponding point on the regression line.
#
# ![](Images/regression_cartoon.png)

# %%
Y = produce101_df['vote_1']
Y2 = produce101_df['vote_2']
X = pd.DataFrame(produce101_df, 
                 columns = ['expo_1', 'expo_2', 'neg_1', 'order_name'
                            , 'order_agency', 'level_1','level_2'
                            , 'agency_category', 'age', 'height', 'visual'
                            , 'agency_member_count', 'is_ranker_same_agency_1', 'is_ranker_same_agency_2' ])
X.head()
# Out:
#       expo_1  expo_2  neg_1  order_name  order_agency  level_1  level_2  \
# name
# 김세정      105     104      0           0             0        5        5
# 전소미      171      63      0           0             0        5        4
# 최유정      134      71      0           0             0        2        5
# 주결경        6      31      0           0             0        5        5
# 강미나       34     100      0           1             0        5        5
#
#       agency_category  age  height  visual  agency_member_count  \
# name
# 김세정                 3   20   164.0       1                    3
# 전소미                 3   15   168.0       1                    1
# 최유정                 3   17   159.0       0                    5
# 주결경                 3   18   166.0       1                    7
# 강미나                 3   17   162.0       0                    3
#
#       is_ranker_same_agency_1  is_ranker_same_agency_2
# name
# 김세정                         1                        1
# 전소미                         0                        0
# 최유정                         1                        1
# 주결경                         1                        1
# 강미나                         1                        1

# %% [markdown]
# # Preprocessing

# %%
# Category 값을 제외한 실수값 preprocessing
X_prepro = X

X_prepro[['expo_1']] = scale (X[['expo_1']])
X_prepro[['expo_2']] = scale (X[['expo_2']])
X_prepro[['age']] = scale (X[['age']])
X_prepro[['height']] = scale (X[['height']])
X_prepro[['level_1']] = scale (X[['level_1']])
X_prepro[['level_2']] = scale (X[['level_2']])
X_prepro[['agency_member_count']] = scale (X[['agency_member_count']])
X_prepro
# Out:
#           expo_1    expo_2  neg_1  order_name  order_agency   level_1  \
# name
# 김세정     1.577921  3.171328      0           0             0  1.662945
# 전소미     3.060435  1.638468      0           0             0  1.662945
# 최유정     2.229329  1.937563      0           0             0 -0.567087
# 주결경    -0.645850  0.442090      0           0             0  1.662945
# 강미나    -0.016905  3.021780      0           1             0  1.662945
# 기희현     1.263448 -0.006552      0           1             0  0.176257
# 김다니     0.387417 -0.380421      0           1             0  0.919601
# 정채연    -0.556001  0.554250      0           0             0  0.176257
# 김나영     0.679428  0.928118      0           1             0  1.662945
# 전소연     0.432342  0.292542      0           0             1  1.662945
# 김소혜     2.880736  4.068612      0           0             0 -1.310431
# 유연정     0.522191  1.301987      0           0             0  0.919601
# 김도연     0.095407 -0.604742      0           0             0  0.919601
# 김청하     0.769277 -0.156100      0           0             0  1.662945
# 허찬미     2.206866  0.629024      1           0             0  1.662945
# 권은빈     0.185256  0.479476      0           1             1  1.662945
# 응 씨 카이 -0.690775  1.227213      0           0             0  0.919601
# 정은우    -0.623388  0.255155      0           0             0 -0.567087
# 김주나     3.756767  1.601081      0           0             0  0.176257
# 박소연    -0.061829  0.591637      0           0             0  1.662945
# 윤채경     0.185256  1.750628      0           0             1 -0.567087
# 한혜리    -0.421227 -0.230873      0           0             0  0.176257
# 김소희    -0.421227 -0.230873      0           0             0  0.176257
# 임나영    -0.241528 -0.043939      0           0             0  0.919601
# 안예슬    -0.016905  1.713242      0           0             0  0.919601
# 박시연    -0.421227  1.563694      0           0             0  0.919601
# 조시윤    -0.219066 -0.455194      0           0             1 -0.567087
# is_ranker_same_agency_1  5.699e+04    3.1e+04      1.837      0.070     -4710.917  1.19e+05
# is_ranker_same_agency_2 -6887.4651   2.96e+04     -0.233      0.817     -6.58e+04   5.2e+04
# ==============================================================================
# Omnibus:                        3.292   Durbin-Watson:                   1.475
# Prob(Omnibus):                  0.193   Jarque-Bera (JB):                3.501
# Skew:                          -0.028   Prob(JB):                        0.174
# Kurtosis:                       3.929   Cond. No.                         19.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Collinearity(공선성) 확인

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(np.corrcoef(X_prepro.T), annot=True, square=True, fmt='.2f', annot_kws={'size':15},
            yticklabels=X_prepro.columns, xticklabels=X_prepro.columns)

# %% [markdown]
# # Collinearity Review
# - expo_1 & expo_2 is higher than others
#     - 프로듀스101 1~4회와 5~7회간에 방송에 노출된 연습생이 집중되어 있음
#
#
# - expo_1 & neg_1 is higher than others
#     - 프로듀스101 1~4회에 연습생의 부정적인 모습을 방송에 많이 노출시킴
#
#
# - expo_2 & level_2 is higher than others
#     - 레벨 평가가 높으면 방송에 많이 노출됨
#
#
# - level_1 & level_2 is higher than others
#     - 1,2 차 레벨 평가 피처는 최종 결과인 level_2 만 사용해야 함
#
#
# - level_2 & agency_category is higher than others
#     - 가능성 1 : 대형기획사에 합격한 것은 실력이 높고 따라서 레벨 평가가 높음
#     - 가능성 2 : 대형기획사 체면상 실력이 있는 아이돌을 출현시킴
#     - 가능성 3 : 대형기획사라서 실력이 높게 평가됨 (방송 1화에 연습생들의 개인인터뷰때 언급됨)
#
#
# - agency_member_count & is_ranker_same_agency_1 is higher than others
#     - 11명 의무투표로 인해 11위권 연습생들과 같은 소속사 연습생도 득표를 받을 확률 증가
#
#
# - is_ranker_same_agency_1 & is_ranker_same_agency_2 is the highest (0.70)
#     - 1,2차 방출 평가 간 11위 까지의 연습생 여부가 너무 공선성이 크므로 is_ranker_same_agency_2만 사용
#
#
# - is_ranker_same_agency_1 & agency_category is the highest (0.70)
#     - 11위 까지의 연습생 여부는 소속사의 크기와 비례

# %% [markdown]
# # 1) Feature selection with pure profile

# %%
X_prepro_profile = X_prepro.drop(labels = ['expo_1', 'expo_2', 'neg_1', 'order_name', 'order_agency'
                                           , 'level_1', 'height', 'age', 'agency_member_count'
                                           , 'is_ranker_same_agency_1', 'is_ranker_same_agency_1', 'is_ranker_same_agency_2'], axis=1)
print( OLS_result(Y, X_prepro_profile).summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vote_1   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     61.94
# Date:                Tue, 05 Apr 2016   Prob (F-statistic):           3.46e-22
# Time:                        22:15:48   Log-Likelihood:                -1235.0
# No. Observations:                  97   AIC:                             2476.
# Df Residuals:                      94   BIC:                             2484.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# level_2          3.727e+04   8683.480      4.292      0.000         2e+04  5.45e+04
# agency_category  3.523e+04   3939.152      8.944      0.000      2.74e+04  4.31e+04
# visual           1.135e+05   2.79e+04      4.060      0.000       5.8e+04  1.69e+05
# ==============================================================================
# Omnibus:                       30.325   Durbin-Watson:                   0.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.561
# Skew:                           1.223   Prob(JB):                     1.17e-13
# Kurtosis:                       5.958   Cond. No.                         7.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Y2.sort_values(ascending=False).head(11)
# Out:
# name
# 김세정    1473685
# 최유정    1286447
# 강미나    1212720
# 전소미    1201490
# 김나영     931084
# 주결경     885556
# 김도연     841749
# 김소혜     833101
# 정채연     696808
# 유연정     684660
# 임나영     665898
# Name: vote_2, dtype: int64

# %% [markdown]
# # Accuracy = :(
# # But I realize pure profile affect to vote

# %%
# 추정값 확인
model_OLS = sm.OLS(Y, X_prepro_profile) 
result_OLS = model_OLS.fit()
prediction = result_OLS.fittedvalues 
print_full(prediction.sort_values(ascending=False).head(11))
# Out:
# name
# 김세정    272298.822531
# 주결경    272298.822531
# 김도연    272298.822531
# 기희현    272298.822531
# 박시연    247030.031075
# 전소미    247030.031075
# 정채연    221761.239619
# 김지성    211797.514285
# 이수현    211797.514285
# 권은빈    196492.448163
# 서혜린    161259.931374
# dtype: float64

# %% [markdown]
# # Outlier detection

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sm.graphics.influence_plot( OLS_result(Y, X_prepro), plot_alpha=0.3, ax=ax)
plt.show()

# 질문 feature가 8개 이상이면 influence_plot을 못그린다?!

# %%
outlier = np.nonzero( OLS_result(Y, X_prepro).outlier_test().ix[:, -1].abs() < 0.01)[0]
outlier
# Out:
# array([], dtype=int64)

# %% [markdown]
# # Model export

# %%
# open the file for writing as binary
fileObject = open("produce101_OLS_profile", 'wb') 

# this writes the object
pickle.dump( OLS_result(Y, X_prepro), fileObject ) 

# here we close the fileObject
fileObject.close()

# %%
# we open the file for reading as binary
fileObject = open("produce101_OLS_profile", 'rb')  

# load the object from the file
model_1 = pickle.load(fileObject)  
# print(model_1.summary())

# %% [markdown]
# # 2) Feature Selection with Focusing Broadcast&Agency (carry)
# ## 2-1)  Before Outlier Removal

# %%
X_prepro_carry = X_prepro.drop(labels = ['level_1',], axis=1)
print( OLS_result(Y, X_prepro_carry).summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vote_1   R-squared:                       0.845
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     35.16
# Date:                Tue, 05 Apr 2016   Prob (F-statistic):           1.89e-28
# Time:                        22:15:49   Log-Likelihood:                -1197.6
# No. Observations:                  97   AIC:                             2421.
# Df Residuals:                      84   BIC:                             2455.
# Df Model:                          13
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# expo_1                   2.695e+04   7754.660      3.475      0.001      1.15e+04  4.24e+04
# expo_2                   3.721e+04   7490.643      4.968      0.000      2.23e+04  5.21e+04
# neg_1                   -2.311e+04    4.7e+04     -0.492      0.624     -1.17e+05  7.03e+04
# order_name              -5429.5761   2.25e+04     -0.242      0.810     -5.01e+04  3.92e+04
# order_agency            -2.972e+04   2.67e+04     -1.114      0.268     -8.28e+04  2.33e+04
# level_2                  1.575e+04   7157.097      2.200      0.031      1513.119     3e+04
# agency_category          3.226e+04   3952.483      8.161      0.000      2.44e+04  4.01e+04
# age                     -9732.1948   6681.716     -1.457      0.149      -2.3e+04  3555.129
# height                   4556.5254   6546.655      0.696      0.488     -8462.215  1.76e+04
# visual                   8.798e+04   2.14e+04      4.119      0.000      4.55e+04   1.3e+05
# agency_member_count     -1.714e+04   7112.157     -2.410      0.018     -3.13e+04 -2998.147
# is_ranker_same_agency_1  4.812e+04   3.16e+04      1.522      0.132     -1.47e+04  1.11e+05
# is_ranker_same_agency_2   849.4499   3.02e+04      0.028      0.978     -5.92e+04  6.09e+04
# ==============================================================================
# Omnibus:                        4.729   Durbin-Watson:                   1.446
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                6.413
# Skew:                           0.021   Prob(JB):                       0.0405
# Kurtosis:                       4.259   Cond. No.                         18.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_prepro_carry1 = X_prepro_carry.drop(labels = ['neg_1', 'order_agency', 'order_name'
                                                ,'height', 'age', 'is_ranker_same_agency_1'], axis=1)
print( OLS_result(Y, X_prepro_carry1).summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vote_1   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     65.03
# Date:                Tue, 05 Apr 2016   Prob (F-statistic):           1.81e-32
# Time:                        22:15:49   Log-Likelihood:                -1200.6
# No. Observations:                  97   AIC:                             2415.
# Df Residuals:                      90   BIC:                             2433.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# expo_1                   2.305e+04   7144.347      3.227      0.002      8858.435  3.72e+04
# expo_2                   3.812e+04   7212.680      5.285      0.000      2.38e+04  5.24e+04
# level_2                  1.748e+04   6799.011      2.571      0.012      3973.974   3.1e+04
# agency_category          3.051e+04   3449.552      8.845      0.000      2.37e+04  3.74e+04
# visual                    9.87e+04   2.05e+04      4.808      0.000      5.79e+04  1.39e+05
# agency_member_count     -1.471e+04   6847.414     -2.148      0.034     -2.83e+04 -1106.192
# is_ranker_same_agency_2  4.636e+04   1.88e+04      2.466      0.016      9016.573  8.37e+04
# ==============================================================================
# Omnibus:                        5.245   Durbin-Watson:                   1.325
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                7.124
# Skew:                           0.139   Prob(JB):                       0.0284
# Kurtosis:                       4.298   Cond. No.                         8.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Accuracy = 63.63% :(

# %%
Y2.sort_values(ascending=False).head(11)
# Out:
# name
# 김세정    1473685
# 최유정    1286447
# 강미나    1212720
# 전소미    1201490
# 김나영     931084
# 주결경     885556
# 김도연     841749
# 김소혜     833101
# 정채연     696808
# 유연정     684660
# 임나영     665898
# Name: vote_2, dtype: int64

# %%
model_OLS1 = sm.OLS(Y, X_prepro_carry1) 
result_OLS1 = model_OLS1.fit()
prediction1 = result_OLS1.fittedvalues 
print_full(prediction.sort_values(ascending=False).head(11))
# Out:
# name
# 김세정    272298.822531
# 주결경    272298.822531
# 김도연    272298.822531
# 기희현    272298.822531
# 박시연    247030.031075
# 전소미    247030.031075
# 정채연    221761.239619
# 김지성    211797.514285
# 이수현    211797.514285
# 권은빈    196492.448163
# 서혜린    161259.931374
# dtype: float64

# %% [markdown]
# # 2) Feature Selection with Focusing Agency (carry)
# ## 2-2) After Outlier Removal

# %%
X_prepro_carry = X_prepro.drop(labels = ['neg_1', 'order_name', 'order_agency'
                                          ,'level_1', 'age', 'height', 'is_ranker_same_agency_1'], axis=1)
print( OLS_result(Y, X_prepro_carry).summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vote_1   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     65.03
# Date:                Tue, 05 Apr 2016   Prob (F-statistic):           1.81e-32
# Time:                        22:15:49   Log-Likelihood:                -1200.6
# No. Observations:                  97   AIC:                             2415.
# Df Residuals:                      90   BIC:                             2433.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# expo_1                   2.305e+04   7144.347      3.227      0.002      8858.435  3.72e+04
# expo_2                   3.812e+04   7212.680      5.285      0.000      2.38e+04  5.24e+04
# level_2                  1.748e+04   6799.011      2.571      0.012      3973.974   3.1e+04
# agency_category          3.051e+04   3449.552      8.845      0.000      2.37e+04  3.74e+04
# visual                    9.87e+04   2.05e+04      4.808      0.000      5.79e+04  1.39e+05
# agency_member_count     -1.471e+04   6847.414     -2.148      0.034     -2.83e+04 -1106.192
# is_ranker_same_agency_2  4.636e+04   1.88e+04      2.466      0.016      9016.573  8.37e+04
# ==============================================================================
# Omnibus:                        5.245   Durbin-Watson:                   1.325
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                7.124
# Skew:                           0.139   Prob(JB):                       0.0284
# Kurtosis:                       4.298   Cond. No.                         8.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Outlier detection

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sm.graphics.influence_plot( OLS_result(Y, X_prepro_carry), plot_alpha=0.3, ax=ax)
plt.show()

# 질문 feature가 8개 이상이면 influence_plot을 못그린다?!

# %%
outlier = np.nonzero( OLS_result(Y, X_prepro_carry).outlier_test().ix[:, -1].abs() < 0.01)[0]
outlier
# Out:
# array([], dtype=int64)

# %%
print(X_prepro_carry.ix[outlier])
# Out:
# Empty DataFrame
# Columns: [expo_1, expo_2, level_2, agency_category, visual, agency_member_count, is_ranker_same_agency_2]
# Index: []

# %%
X_prepro_carry_out = X_prepro_carry.drop(X_prepro.index[outlier])
Y_out = Y.drop(X_prepro.index[outlier])
X_prepro_carry_out.head()
# 아웃라이어 샘플 제거된 결과
# Out:
#         expo_1    expo_2   level_2  agency_category  visual  \
# name
# 김세정   1.577921  3.171328  1.426050                3       1
# 전소미   3.060435  1.638468  0.747977                3       1
# 최유정   2.229329  1.937563  1.426050                3       0
# 주결경  -0.645850  0.442090  1.426050                3       1
# 강미나  -0.016905  3.021780  1.426050                3       0
#
#       agency_member_count  is_ranker_same_agency_2
# name
# 김세정             -0.197431                        1
# 전소미             -1.067920                        0
# 최유정              0.673059                        1
# 주결경              1.543548                        1
# 강미나             -0.197431                        1

# %%
Y_out.head()
# Out:
# name
# 김세정    559694
# 전소미    528772
# 최유정    392773
# 주결경    387537
# 강미나    376977
# Name: vote_1, dtype: int64

# %%
print( OLS_result(Y_out, X_prepro_carry_out).summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vote_1   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     65.03
# Date:                Tue, 05 Apr 2016   Prob (F-statistic):           1.81e-32
# Time:                        22:15:49   Log-Likelihood:                -1200.6
# No. Observations:                  97   AIC:                             2415.
# Df Residuals:                      90   BIC:                             2433.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# expo_1                   2.305e+04   7144.347      3.227      0.002      8858.435  3.72e+04
# expo_2                   3.812e+04   7212.680      5.285      0.000      2.38e+04  5.24e+04
# level_2                  1.748e+04   6799.011      2.571      0.012      3973.974   3.1e+04
# agency_category          3.051e+04   3449.552      8.845      0.000      2.37e+04  3.74e+04
# visual                    9.87e+04   2.05e+04      4.808      0.000      5.79e+04  1.39e+05
# agency_member_count     -1.471e+04   6847.414     -2.148      0.034     -2.83e+04 -1106.192
# is_ranker_same_agency_2  4.636e+04   1.88e+04      2.466      0.016      9016.573  8.37e+04
# ==============================================================================
# Omnibus:                        5.245   Durbin-Watson:                   1.325
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                7.124
# Skew:                           0.139   Prob(JB):                       0.0284
# Kurtosis:                       4.298   Cond. No.                         8.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Outlier review
# - Selecting features is dependent on outlier

# %% [markdown]
# # Accuracy = 72.72%
#
# - 각 미션 현장투표 따른 결과에 의한 가산표 1천표, 10만표, 15만표가 가산 되는 변수 발생
# - 현장투표는 모수를 추정하기 어려운 표본
# - 이것을 회귀분석하는 것은 비지니스적으로 의미없으므로 분석 요소에서 제외

# %%
Y2.sort_values(ascending=False).head(11)
# Out:
# name
# 김세정    1473685
# 최유정    1286447
# 강미나    1212720
# 전소미    1201490
# 김나영     931084
# 주결경     885556
# 김도연     841749
# 김소혜     833101
# 정채연     696808
# 유연정     684660
# 임나영     665898
# Name: vote_2, dtype: int64

# %%
# 추정값 확인 (Without Outlier)
model_OLS2 = sm.OLS(Y_out, X_prepro_carry_out) 
result_OLS2 = model_OLS2.fit()
prediction2 = result_OLS2.fittedvalues 
print_full(prediction2.sort_values(ascending=False).head(11))
# Out:
# name
# 김세정    421684.795143
# 전소미    352022.913243
# 기희현    293300.180454
# 강미나    280523.586475
# 최유정    278170.339038
# 박시연    276857.257303
# 김소혜    275743.273055
# 정채연    249027.886987
# 주결경    240779.244363
# 김도연    230767.916485
# 유연정    227395.152209
# dtype: float64

# %% [markdown]
# ### True Positive = 김세정, 전소미, ~~기희현~~ ,강미나, 최유정, ~~박시연~~, 김소혜, 정채연, ~~주결경~~, 김도연

# %% [markdown]
# # But... final result is
# (https://en.wikipedia.org/wiki/Produce_101#Result)
#
# # Accuracy(final) = 81.81%
#
# True(final)  = 전소미(JYP), 김세정(젤리피쉬), 최유정(판타지오), 김청하(M&H), 김소혜(레드라인), 주결경(플레디스), 정채연(MBK), 김도연(판타지오), 강미나(젤리피쉬), 임나영(플레디스), 유연정(스타쉽)
#
# True Positive = 김세정, 전소미, ~~기희현~~ ,강미나, 최유정, ~~박시연~~, 김소혜, 정채연, 주결경, 김도연

# %% [markdown]
# # Result
# ## 1. 득표에 영향미치는 것
#
#  0) visual
#     - 같은 여성이 봤을때 호감가는 외모
#
#  1) is_ranker_same_agency_2
#     - 같은 소속사 연습생이 상위 11위에 있는지 여부
#
#
#  2) agency_category
#     - 소속사 크기(대형, 중소형, 개인)
#
#
#  3) expo_1, expo_2
#     - 방송노출 시간
#
#
#  4) agency_member_count
#     - 같은 소속사 연습생 수
#     - 각 인원이 소속사 팬덤의 표를 나눠먹는 카니발 발생(추측)
#
#
#  5) level_2
#     - 2번째(최종) 레벨 테스트

# %% [markdown]
# ## 2. 내가 만약 연예기획사 대표라면? (프로듀스 101 시즌2 준비)
# 1. 인지도와 기대치가 높은(대형) 소속사가 유리하다!
# 2. 첫방부터 카메라 샷을 잡는자가 승리한다!
# 3. 최대 3명까지만 같이 출연시켜라! 특히, 각 연습의 외모, 특기, 성격이 다른 스타일을 함께 내보내라!
# 4. 실력은 어느정도 겸비되어 있어야 한다!
# 5. 아이돌에겐 역시 비주얼도 무시할 수 없다!

# %% [markdown]
# ## 3. 내가 만약 시청자라면?
# ### 예측 11위안에 있는 기획사 주식을 구입
# (ex : 판티지오, 큐브)
# ![stock](Images/stock.jpg)

# %% [markdown]
# # Model export

# %%
# open the file for writing as binary
fileObject = open("produce101_OLS_carry", 'wb') 

# this writes the object
pickle.dump( OLS_result(Y_out, X_prepro_carry_out), fileObject ) 

# here we close the fileObject
fileObject.close()

# %%
# we open the file for reading as binary
fileObject = open("produce101_OLS_carry", 'rb')  

# load the object from the file
model_1 = pickle.load(fileObject)  
# print(model_1.summary())

# %% [markdown]
# # RidgeCV / LassoCV / ElasticNetCV
# ## 복수의 alpha 값에 대해 자동으로 fit 및 최적값을 찾음

# %%
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV

# %%
alphas = np.logspace(-4, -0.01)
ridge_cv = RidgeCV(alphas=alphas)
ridge_cv.fit(X_prepro_carry_out, Y_out)
lasso_cv = LassoCV(alphas=alphas)
lasso_cv.fit(X_prepro_carry_out, Y_out)
elastic_cv = ElasticNetCV(alphas=alphas)
elastic_cv.fit(X_prepro_carry_out, Y_out)

print("alphas : ", alphas)
print("\n")
print("ridge_cv : ", ridge_cv.alpha_ )
print("lasso_cv : ", lasso_cv.alpha_ )
print("elastic_cv : ", elastic_cv.alpha_ )
# Out:
# alphas :  [  1.00000000e-04   1.20622568e-04   1.45498040e-04   1.75503473e-04
#    2.11696796e-04   2.55354113e-04   3.08014689e-04   3.71535229e-04
#    4.48155336e-04   5.40576476e-04   6.52057229e-04   7.86528177e-04
#    9.48730488e-04   1.14438308e-03   1.38038426e-03   1.66505495e-03
#    2.00843205e-03   2.42262232e-03   2.92222926e-03   3.52486799e-03
#    4.25178630e-03   5.12861384e-03   6.18626573e-03   7.46203261e-03
#    9.00089539e-03   1.08571112e-02   1.30961264e-02   1.57968840e-02
#    1.90546072e-02   2.29841566e-02   2.77240800e-02   3.34414973e-02
#    4.03379929e-02   4.86567231e-02   5.86909891e-02   7.07945784e-02
#    8.53942388e-02   1.03004724e-01   1.24246944e-01   1.49869855e-01
#    1.80776868e-01   2.18057701e-01   2.63026799e-01   3.17269681e-01
#    3.82698837e-01   4.61621167e-01   5.56819307e-01   6.71649750e-01
#    8.10161178e-01   9.77237221e-01]
#
#
# ridge_cv :  0.977237220956
# lasso_cv :  0.977237220956
# elastic_cv :  0.0001

# %% [markdown]
# # Regularize

# %%
# OLS_regularized
print( OLS_regularized(Y_out, X_prepro_carry_out, lasso_cv.alpha_).summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vote_1   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     65.03
# Date:                Tue, 05 Apr 2016   Prob (F-statistic):           1.81e-32
# Time:                        22:15:49   Log-Likelihood:                -1200.6
# No. Observations:                  97   AIC:                             2415.
# Df Residuals:                      90   BIC:                             2433.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# expo_1                   2.305e+04   7144.347      3.227      0.002      8858.337  3.72e+04
# expo_2                   3.812e+04   7212.680      5.285      0.000      2.38e+04  5.24e+04
# level_2                  1.748e+04   6799.011      2.571      0.012      3974.407   3.1e+04
# agency_category          3.051e+04   3449.552      8.846      0.000      2.37e+04  3.74e+04
# visual                   9.869e+04   2.05e+04      4.808      0.000      5.79e+04  1.39e+05
# agency_member_count     -1.471e+04   6847.414     -2.148      0.034     -2.83e+04 -1103.956
# is_ranker_same_agency_2  4.635e+04   1.88e+04      2.466      0.016      9009.673  8.37e+04
# ==============================================================================
# Omnibus:                        5.246   Durbin-Watson:                   1.325
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                7.127
# Skew:                           0.139   Prob(JB):                       0.0283
# Kurtosis:                       4.299   Cond. No.                         8.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Regularize
# - 필요성이 적음
# - 이유는?!

# %% [markdown]
# ## Intercept 없는 모델 성능이 높다

# %%
#Intercept 넣고 모델확인
X_prepro_carry_out_intercept = sm.add_constant(X_prepro_carry_out)
print( OLS_result(Y_out, X_prepro_carry_out_intercept).summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vote_1   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     33.63
# Date:                Tue, 05 Apr 2016   Prob (F-statistic):           2.03e-22
# Time:                        22:15:49   Log-Likelihood:                -1200.3
# No. Observations:                  97   AIC:                             2417.
# Df Residuals:                      89   BIC:                             2437.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# const                   -2.549e+04   3.39e+04     -0.753      0.454     -9.28e+04  4.18e+04
# expo_1                   2.306e+04   7161.622      3.221      0.002      8834.410  3.73e+04
# expo_2                   3.759e+04   7263.623      5.176      0.000      2.32e+04   5.2e+04
# level_2                  1.674e+04   6886.376      2.431      0.017      3056.042  3.04e+04
# agency_category          4.223e+04   1.59e+04      2.649      0.010      1.06e+04  7.39e+04
# visual                   9.775e+04   2.06e+04      4.742      0.000      5.68e+04  1.39e+05
# agency_member_count      -1.52e+04   6894.147     -2.204      0.030     -2.89e+04 -1496.492
# is_ranker_same_agency_2  3.807e+04   2.18e+04      1.744      0.085     -5291.535  8.14e+04
# ==============================================================================
# Omnibus:                        4.392   Durbin-Watson:                   1.333
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                5.400
# Skew:                           0.108   Prob(JB):                       0.0672
# Kurtosis:                       4.135   Cond. No.                         16.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # SVR(Support Vector Regression)

# %%
print("\n ##Support Vector Regression Score##")
from sklearn.svm import SVR
svr_linear = SVR(kernel='linear')
svr_poly = SVR(kernel='poly')
svr_sigmoid = SVR(kernel='sigmoid')
svr_rbf = SVR(kernel='rbf')

score_l = svr_linear.fit(X_prepro_carry_out, Y_out).score(X_prepro_carry_out ,Y_out)
score_s = svr_sigmoid.fit(X_prepro_carry_out, Y_out).score(X_prepro_carry_out ,Y_out)
score_r = svr_rbf.fit(X_prepro_carry_out, Y_out).score(X_prepro_carry_out ,Y_out)
score_p = svr_poly.fit(X_prepro_carry_out, Y_out).score(X_prepro_carry_out ,Y_out)

print("SVR_linear model(score)  : ", score_l)
print("SVR_poly model(score)    : ", score_p)
print("SVR_sigmoid model(score) : ", score_s)
print("SVR_rbf model(score)     : ", score_r)
# Out:
#  ##Support Vector Regression Score##
# SVR_linear model(score)  :  -0.194499374917
# SVR_poly model(score)    :  -0.194852292979
# SVR_sigmoid model(score) :  -0.196256289402
# SVR_rbf model(score)     :  -0.19610261024
